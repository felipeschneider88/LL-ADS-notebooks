# %% [markdown]
# # Titulo 1

# %%
Get-Process
# Out:
# Handles  NPM(K)    PM(K)      WS(K)     CPU(s)     Id  SI ProcessName
# -------  ------    -----      -----     ------     --  -- -----------
#     140       9     1556       3756   1,580.89   6616   2 ApMsgFwd
#     155      10     1784       4664      74.27  11032   2 ApntEx
#     354      20     4544      10140      87.63  13784   2 Apoint
#     557      31    22616      34080      15.38  16572   2 ApplicationFrameHost
#     211      13    11096      17416      33.27   9448   0 audiodg
#     419      89    99932      92752      19.69   3924   2 azuredatastudio
#     669      30   203924     173408      14.88   7464   2 azuredatastudio
#     723      39    35020      66420      12.95  12792   2 azuredatastudio
#     229      21    16672      24320       0.22  16980   2 azuredatastudio
#     363      23     9200      21996       0.20  18176   2 azuredatastudio
#     407      38    41992      55164       2.41  18804   2 azuredatastudio
# ...
