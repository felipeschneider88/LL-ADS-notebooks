# %% [markdown]
# # Notebook de prueba de python
#
# ![alt text](https://www.cuti.org.uy/data/f/c/socios/112/160x160/pyxis.jpg "Texto logo")

# %% [markdown]
# ## Instalamos los pre requisitos
# En este caso vamos a necesitar la libreria de request para hacer consultas HTTP

# %%
pip --version
# Out:
# pip 19.2.3 from c:\users\felipe\azuredatastudio-python\0.0.1\lib\site-packages\pip (python 3.6)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow, requests
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: 'pillow,'
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # El viejo y querido Hola mundo

# %%
#Primero validamos que el kernel de python está andando
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ## Prueba de código más complejo
#
# Vamos a intentar obtener una imagen al azar usando una API de perros

# %%
#Agrego todas las librerias necesasrias
from PIL import Image
from io import BytesIO
import requests
import json

urlPerro = 'https://dog.ceo/api/breeds/image/random'

imgUri = json.loads(requests.get(urlPerro).content)["message"]

arreByte = requests.get(imgUri)

img = Image.open(BytesIO(arreByte.content))

display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=899x899 at 0x13F03CD63C8>
